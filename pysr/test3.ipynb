# %%
import pandas as pd
import numpy as np
from update_expressions import update_expressions

# 读取并准备数据
df = pd.read_csv('./train.csv')
data = np.array(df)
X = data[:, :-1]
y = data[:, -1].reshape(-1)

# 构建数据字典
dataset = {
    'data': {
        'inputs': X,
        'outputs': y
    }
}

# 使用update_expressions函数处理数据并更新文件
update_expressions('specification_oscillator1_body.txt', dataset)

print("处理完成！请检查 specification_oscillator1_body.txt 文件")
# Out:
# Detected IPython. Loading juliacall extension. See https://juliapy.github.io/PythonCall.jl/stable/compat/#IPython
# 开始训练符号回归模型...
# Compiling Julia backend...
# c:\anacoda\envs\LLM-SR-main\Lib\site-packages\pysr\sr.py:2766: UserWarning: Note: it looks like you are running in Jupyter. The progress bar will be turned off.
#   warnings.warn(
# [ Info: Started!
# Expressions evaluated per second: 4.160e+04
# Progress: 279 / 1240 total iterations (22.500%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.363e-03  1.594e+01  y = 0.014333
# 3           4.230e-04  1.167e+00  y = x₀ * -0.16178
# 4           4.191e-04  9.299e-03  y = sin(x₀) * -0.16799
# 5           4.185e-04  1.377e-03  y = (x₀ - -0.013431) * -0.16318
# 6           1.953e-04  7.623e-01  y = exp(x₁) * (x₀ * -0.16535)
# 7           3.178e-05  1.816e+00  y = (x₀ / -2.0837) * (x₁ - -0.34313)
# 8           2.591e-05  2.044e-01  y = ((-0.35357 - x₁) * 0.48118) * sin(x₀)
# 12          2.007e-05  6.388e-02  y = ((x₀ / -0.19178) * 0.056043) / (exp(x₁ / -0.3717) * 1....
#                                       8396)
# 13          2.000e-05  3.234e-03  y = (((x₁ / (0.88543 / (x₁ + 0.93716))) + 0.36436) * x₀) /...
#                                        -2.2869
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.820e+04
# Progress: 466 / 1240 total iterations (37.581%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.363e-03  1.594e+01  y = 0.014333
# 3           4.230e-04  1.167e+00  y = x₀ * -0.16178
# 4           4.191e-04  9.299e-03  y = sin(x₀) * -0.16799
# 5           4.185e-04  1.377e-03  y = (x₀ - -0.013431) * -0.16318
# 6           1.953e-04  7.623e-01  y = exp(x₁) * (x₀ * -0.16535)
# 7           3.177e-05  1.816e+00  y = x₀ * (-0.16471 - (x₁ * 0.48243))
# 8           2.591e-05  2.041e-01  y = ((-0.35357 - x₁) * 0.48118) * sin(x₀)
# 9           1.908e-05  3.061e-01  y = log(cos(-0.39553 - x₁) + -0.067542) * x₀
# 15          1.726e-05  1.664e-02  y = log(exp((cos(x₁) - (x₁ + (x₁ * -0.5254))) + -1.1655)) ...
#                                       * sin(x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 3.280e+04
# Progress: 618 / 1240 total iterations (49.839%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.363e-03  1.594e+01  y = 0.014333
# 3           4.230e-04  1.167e+00  y = x₀ * -0.16178
# 4           4.191e-04  9.299e-03  y = sin(x₀) * -0.16799
# 5           4.185e-04  1.377e-03  y = (x₀ - -0.013431) * -0.16318
# 6           1.953e-04  7.623e-01  y = exp(x₁) * (x₀ * -0.16535)
# 7           3.177e-05  1.816e+00  y = x₀ * (-0.16471 - (x₁ * 0.48243))
# 8           2.591e-05  2.041e-01  y = ((-0.35357 - x₁) * 0.48118) * sin(x₀)
# 9           1.908e-05  3.061e-01  y = log(cos(-0.39553 - x₁) + -0.067542) * x₀
# 15          1.726e-05  1.664e-02  y = log(exp((cos(x₁) - (x₁ + (x₁ * -0.5254))) + -1.1655)) ...
#                                       * sin(x₀)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.970e+04
# Progress: 732 / 1240 total iterations (59.032%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.363e-03  1.594e+01  y = 0.014333
# 3           4.230e-04  1.167e+00  y = x₀ * -0.16178
# 4           4.191e-04  9.299e-03  y = sin(x₀) * -0.16799
# 5           4.185e-04  1.377e-03  y = (x₀ - -0.013431) * -0.16318
# 6           1.953e-04  7.623e-01  y = exp(x₁) * (x₀ * -0.16535)
# 7           3.177e-05  1.816e+00  y = x₀ * (-0.16471 - (x₁ * 0.48243))
# 8           2.542e-05  2.231e-01  y = ((-0.34466 - x₁) * 0.49647) * sin(x₀)
# 9           1.908e-05  2.870e-01  y = log(cos(-0.39553 - x₁) + -0.067542) * x₀
# 13          1.884e-05  3.187e-03  y = sin(sin(x₀) + x₀) * ((-0.25447 - (x₁ * 0.6389)) * 0.38...
#                                       205)
# 14          1.512e-05  2.199e-01  y = (sin(x₀ + sin(x₀)) * (-0.25447 - (x₁ * cos(0.81946))))...
#                                        * 0.38205
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.570e+04
# Progress: 860 / 1240 total iterations (69.355%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.363e-03  1.594e+01  y = 0.014333
# 3           4.230e-04  1.167e+00  y = x₀ * -0.16178
# 4           4.191e-04  9.299e-03  y = sin(x₀) * -0.16799
# 5           4.185e-04  1.377e-03  y = (x₀ - -0.013431) * -0.16318
# 6           1.953e-04  7.623e-01  y = exp(x₁) * (x₀ * -0.16535)
# 7           3.177e-05  1.816e+00  y = x₀ * (-0.16471 - (x₁ * 0.48243))
# 8           2.542e-05  2.231e-01  y = ((-0.34466 - x₁) * 0.49647) * sin(x₀)
# 9           1.904e-05  2.891e-01  y = (log(cos(-0.42391 - x₁)) + -0.065294) * x₀
# 10          1.448e-05  2.734e-01  y = (-0.35504 - x₁) * (sin(x₀ + x₀) * 0.27044)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.030e+04
# Progress: 988 / 1240 total iterations (79.677%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.363e-03  1.594e+01  y = 0.014333
# 3           4.230e-04  1.167e+00  y = x₀ * -0.16178
# 4           4.191e-04  9.299e-03  y = sin(x₀) * -0.16799
# 5           4.185e-04  1.377e-03  y = (x₀ - -0.013431) * -0.16318
# 6           1.953e-04  7.623e-01  y = exp(x₁) * (x₀ * -0.16535)
# 7           3.177e-05  1.816e+00  y = x₀ * (-0.16471 - (x₁ * 0.48243))
# 8           2.542e-05  2.231e-01  y = ((-0.34466 - x₁) * 0.49647) * sin(x₀)
# 9           1.904e-05  2.891e-01  y = (log(cos(-0.42391 - x₁)) + -0.065294) * x₀
# 10          1.448e-05  2.734e-01  y = (-0.35504 - x₁) * (sin(x₀ + x₀) * 0.27044)
# 11          1.439e-05  6.249e-03  y = (-0.35504 - sin(x₁)) * (0.27044 * sin(x₀ + x₀))
# 12          9.586e-06  4.064e-01  y = (-0.35504 - x₁) * (sin(x₀ + (x₀ + 0.026892)) * 0.27044...
#                                       )
# 15          6.778e-06  1.156e-01  y = (0.27044 * sin(x₀ + sin(x₀ + (x₁ * x₁)))) * (-0.35504 ...
#                                       - x₁)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
#
# Expressions evaluated per second: 2.060e+04
# Progress: 1136 / 1240 total iterations (91.613%)
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.363e-03  1.594e+01  y = 0.014333
# 3           4.230e-04  1.167e+00  y = x₀ * -0.16178
# 4           4.191e-04  9.299e-03  y = sin(x₀) * -0.16799
# 5           4.185e-04  1.377e-03  y = (x₀ - -0.013431) * -0.16318
# 6           1.953e-04  7.623e-01  y = exp(x₁) * (x₀ * -0.16535)
# 7           3.177e-05  1.816e+00  y = x₀ * (-0.16471 - (x₁ * 0.48243))
# 8           2.542e-05  2.231e-01  y = ((-0.34466 - x₁) * 0.49647) * sin(x₀)
# 9           1.904e-05  2.891e-01  y = (log(cos(-0.42391 - x₁)) + -0.065294) * x₀
# 10          1.448e-05  2.734e-01  y = (-0.35504 - x₁) * (sin(x₀ + x₀) * 0.27044)
# 11          1.439e-05  6.249e-03  y = (-0.35504 - sin(x₁)) * (0.27044 * sin(x₀ + x₀))
# 12          9.416e-06  4.244e-01  y = (sin((x₀ + x₀) + 0.029833) * (-0.35475 - x₁)) * 0.2722...
#                                       6
# 14          2.803e-06  6.058e-01  y = (sin((x₀ + x₀) + (x₁ * 0.2018)) * (-0.34899 - x₁)) * 0...
#                                       .2753
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# ════════════════════════════════════════════════════════════════════════════════════════════════════
# Press 'q' and then <enter> to stop execution early.
# [ Info: Final population:
# [ Info: Results saved to:
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# Complexity  Loss       Score      Equation
# 1           4.363e-03  1.594e+01  y = 0.014333
# 3           4.230e-04  1.167e+00  y = x₀ * -0.16178
# 4           4.191e-04  9.299e-03  y = sin(x₀) * -0.16799
# 5           4.185e-04  1.377e-03  y = (x₀ - -0.013431) * -0.16318
# 6           1.953e-04  7.623e-01  y = exp(x₁) * (x₀ * -0.16535)
# 7           3.177e-05  1.816e+00  y = x₀ * (-0.16471 - (x₁ * 0.48243))
# 8           2.542e-05  2.231e-01  y = ((-0.34466 - x₁) * 0.49647) * sin(x₀)
# 9           1.847e-05  3.194e-01  y = (exp(sin(x₁ * 2.9524)) * x₀) * -0.15768
# 10          1.448e-05  2.431e-01  y = (-0.35504 - x₁) * (sin(x₀ + x₀) * 0.27044)
# 11          1.438e-05  6.894e-03  y = (sin(x₀ + x₀) * (-0.35348 - sin(x₁))) * 0.27173
# 12          9.416e-06  4.238e-01  y = (sin((x₀ + x₀) + 0.029833) * (-0.35475 - x₁)) * 0.2722...
#                                       6
# 13          9.358e-06  6.137e-03  y = (sin((x₀ + x₀) + 0.029833) * (-0.35475 - sin(x₁))) * 0...
#                                       .27226
# 14          2.787e-06  1.211e+00  y = (-0.35052 - x₁) * (sin(x₀ + ((x₁ * 0.20775) + x₀)) * 0...
#                                       .27401)
# ───────────────────────────────────────────────────────────────────────────────────────────────────
# 模型训练完成！
# 处理完成！请检查 specification_oscillator1_body.txt 文件
#   - outputs\20250417_015118_ijYGpZ\hall_of_fame.csv
